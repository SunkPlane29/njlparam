# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd 
import scienceplots

plt.style.use(['science', 'notebook', 'grid'])

# %%
# importando os dados de o arquivo csv 
# Dados referentes ao nested sampling 
# com T_pc = 156 MeV \pm 1.5 MeV 
data = pd.read_csv("njlparameters_chain.csv")
data
# Out:
#          iter  chain      Lamb       GL2        mc             w      T_pc
# 0       80000      1  0.607715  1.753360  0.004726  3.719247e-37  0.204154
# 1       80001      1  0.669992  1.726743  0.004078  3.722443e-37  0.204138
# 2       80002      1  0.603587  1.753319  0.004765  3.762268e-37  0.202767
# 3       80003      1  0.602334  1.740047  0.004713  3.794860e-37  0.202347
# 4       80004      1  0.607223  1.739410  0.004664  3.801965e-37  0.203989
# ...       ...    ...       ...       ...       ...           ...       ...
# 28599  108599      1  0.596650  1.748701  0.004809  7.270677e-07  0.200437
# 28600  108600      1  0.625423  1.732561  0.004466  3.427488e-07  0.200331
# 28601  108601      1  0.625811  1.732165  0.004461  8.182976e-08  0.200455
# 28602  108602      1  0.597206  1.748767  0.004804  5.222058e-08  0.200624
# 28603  108603      1  0.626055  1.731603  0.004456  2.817486e-08  0.200533
#
# [28604 rows x 7 columns]

# %%
# plotando as distribuições dos parâmetros 
# Correlacionadas dos parametros 
plt.figure(figsize=(10, 6))
plt.scatter(data['GL2'], data['Lamb'], alpha=0.5, color='blue')
plt.xlabel('$G \Lambda^2$')
plt.ylabel('$\Lambda$ (GeV)')
plt.title('Distribuição Correlacionada de G_S e Lambda')
plt.grid(True)
plt.show()

# %%
# plotando as distribuições dos parâmetros 
# Correlacionadas dos parametros 
plt.figure(figsize=(6, 4))
plt.hist(data['T_pc'],bins=30, color='blue', alpha=0.7)
plt.xlabel('$T_{pc}$ MeV')
plt.ylabel('Densidade')
plt.grid(alpha=0.3)
plt.show()
